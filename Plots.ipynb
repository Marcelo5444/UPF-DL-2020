# %%
from numpy import loadtxt

normal_resnet = loadtxt('resnet18.csv', delimiter=',')
loss_avgpool_2exits = loadtxt('loss_avgpool_2exits.csv', delimiter=',')
loss_Pyramid_3exits = loadtxt('loss_Pyramid_3exits.csv', delimiter=',')
loss_Pyramid_2exits = loadtxt('loss_Pyramid_2exits.csv', delimiter=',')
loss_avgpool_3exits = loadtxt('loss_Avg_3exits.csv', delimiter=',')
#loss_avgpool_3exits = loadtxt('loss_Avg_3exits.csv', delimiter=',')

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (40,40)

# %%
plt.plot(loss_avgpool_2exits/2,'--',c="b")
plt.plot(loss_avgpool_3exits/3,c="b")
plt.plot(loss_Pyramid_2exits/2,'--',c="g")
plt.plot(loss_Pyramid_3exits/3,c="g")
plt.plot(normal_resnet,c="g")
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
loss_Pyramid_3exits
# Out:
# array([179.41597676, 138.97290945, 127.73762703, 120.00776625,
#        115.17010319, 112.49221778, 109.05034888, 107.35606009,
#        106.39063436, 105.35236442, 102.07569271, 101.02092785,
#        100.72303969,  99.87584054,  98.90847856,  98.38574874,
#         97.28235573,  96.52394897,  97.06300908,  98.2812975 ,
#         96.65888494,  95.25675589,  94.45885468,  93.61865634,
#         93.62757957,  89.11750811,  86.7747041 ,  85.72890925,
#         86.61376041,  85.22038227,  83.87287259,  84.42622226,
#         84.810669  ,  83.42730176,  84.49563545,  84.85092896,
#         83.1908533 ,  83.68746537,  82.37744051,  82.3968935 ,
#         82.03376174,  82.14795107,  82.67556477,  82.10237068,
#         82.21910548,  81.28731358,  81.68314755,  82.33320123,
#         81.73306108,  81.88330126,  77.78816634,  76.72724313,
#         75.58946908,  75.80621213,  74.44928688,  74.66047853,
#         74.98199624,  74.7150709 ,  74.56140453,  74.44041228,
# ...
